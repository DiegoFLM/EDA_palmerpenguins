# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.style

import empiricaldist
import scipy.stats

# %%
matplotlib.style.use('seaborn-v0_8-whitegrid')

penguin_color = {
    'Adelie': '#ff6602ff',
    'Gentoo': '#0f7175ff',
    'Chinstrap': '#c65dc9ff'
}

# %% [markdown]
# ## Load palmerpenguins dataset

# %% [markdown]
# Source:
# https://github.com/allisonhorst/palmerpenguins

# %%
penguins_original = pd.read_csv(
    'https://raw.githubusercontent.com/allisonhorst/palmerpenguins/main/inst/extdata/penguins.csv'
    )

# %% [markdown]
# # Remove null values

# %%
nan_indexes = penguins_original.index[penguins_original.isna().any(axis=1)]
penguins = penguins_original.dropna(axis = 0, how = 'any').copy()
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 4       Adelie  Torgersen            36.7           19.3              193.0
# 5       Adelie  Torgersen            39.3           20.6              190.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# 1         3800.0  female  2007
# 2         3250.0  female  2007
# 4         3450.0  female  2007
# 5         3650.0    male  2007
# ..           ...     ...   ...
# 339       4000.0    male  2009
# 340       3400.0  female  2009
# 341       3775.0    male  2009
# 342       4100.0    male  2009
# 343       3775.0  female  2009
#
# [333 rows x 8 columns]

# %% [markdown]
# # Descriptive Statistics

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   333.000000
# mean   2008.042042
# std       0.812944
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
ranges = penguins.max(numeric_only = True) - penguins.min(numeric_only = True)
ranges
# Out:
# bill_length_mm         27.5
# bill_depth_mm           8.4
# flipper_length_mm      59.0
# body_mass_g          3600.0
# year                    2.0
# dtype: float64

# %% [markdown]
# ## Interquartile Range
# Includes 50% of the data

# %%
iqr = (
    penguins.quantile(0.75, numeric_only = True) 
    - penguins.quantile(0.25, numeric_only = True) )
iqr
# Out:
# bill_length_mm          9.1
# bill_depth_mm           3.1
# flipper_length_mm      23.0
# body_mass_g          1225.0
# year                    2.0
# dtype: float64

# %%
(
    penguins
    .quantile([0.25, 0.5, 0.75], numeric_only = True)
    .transpose()
    .rename_axis('variable')
    .reset_index()
    .assign(
        iqr = lambda df: df[0.75] - df[0.25]
    )
)
# Out:
#             variable    0.25     0.5    0.75     iqr
# 0     bill_length_mm    39.5    44.5    48.6     9.1
# 1      bill_depth_mm    15.6    17.3    18.7     3.1
# 2  flipper_length_mm   190.0   197.0   213.0    23.0
# 3        body_mass_g  3550.0  4050.0  4775.0  1225.0
# 4               year  2007.0  2008.0  2009.0     2.0

# %% [markdown]
# # Graphics

# %% [markdown]
# ## histplot

# %%
sns.histplot(
    data = penguins,
    x = 'flipper_length_mm',
    binwidth = 2,
    # hue = 'species',
    
)

plt.axvline(
    x = penguins['flipper_length_mm'].mean(),
    color = 'red',
    linestyle = 'dashed',
    linewidth = 2
)

plt.axvline(
    x = penguins['flipper_length_mm'].median(),
    color = 'blue',
    linestyle = 'dashed',
    linewidth = 2
)

plt.show()

# %% [markdown]
# ## boxplot

# %%
sns.boxplot(
    data = penguins,
    x = 'flipper_length_mm',
)
# Out:
# <AxesSubplot: xlabel='flipper_length_mm'>

# %% [markdown]
# # Distributions

# %% [markdown]
# # PMF

# %%
sns.histplot(
    data = penguins,
    x = 'flipper_length_mm',
    binwidth = 2,
    stat = 'probability',
    # hue = 'species',
    
)

plt.axvline(
    x = penguins['flipper_length_mm'].mean(),
    color = 'red',
    linestyle = 'dashed',
    linewidth = 2
)

plt.axvline(
    x = penguins['flipper_length_mm'].median(),
    color = 'blue',
    linestyle = 'dashed',
    linewidth = 2
)

plt.show()

# %%
pmf_flipper_length_mm = empiricaldist.Pmf.from_seq(
    penguins.flipper_length_mm,
    normalize = True
)

pmf_flipper_length_mm.head()
# Out:
# 172.0    0.003003
# 174.0    0.003003
# 176.0    0.003003
# Name: , dtype: float64

# %%
pmf_flipper_length_mm.bar()

# %%
pmf_flipper_length_mm(190)
# Out:
# 0.06306306306306306

# %% [markdown]
# # eCDF (empirical Cumulative Distribution Function)

# %%
sns.ecdfplot(
    data = penguins,
    x = 'flipper_length_mm',
    # hue = 'species',
)
# Out:
# <AxesSubplot: xlabel='flipper_length_mm', ylabel='Proportion'>

# %%
cdf_flipper_length_mm = empiricaldist.Cdf.from_seq(
    penguins.flipper_length_mm
)

cdf_flipper_length_mm.head()
# Out:
# 172.0    0.003003
# 174.0    0.006006
# 176.0    0.009009
# Name: , dtype: float64

# %%
q = 200
p = cdf_flipper_length_mm[q]
print (q, p)
# Out:
# 200 0.5675675675675675

# %%
cdf_flipper_length_mm.plot()

q = 200
p = cdf_flipper_length_mm[q]

plt.vlines(
    x = q,
    ymin = 0,
    ymax = p,
    color = 'black',
    linestyle = 'dashed',
)

plt.hlines(
    y = p,
    xmin = pmf_flipper_length_mm.qs[0],
    xmax = q,
    color = 'black',
    linestyle = 'dashed',
)

plt.plot(q, p, 'ro')
plt.show()

# %%
cdf_flipper_length_mm.step()
ps = ( 0.25 , 0.75 ) # IQR
qs = cdf_flipper_length_mm.inverse(ps)
plt.vlines (
    x = qs,
    ymin = 0,
    ymax=ps,
    color='black',
    linestyle='dashed'
)

plt.hlines(
   y=ps,
   xmin=pmf_flipper_length_mm.qs[0],
   xmax=qs,
   color='black',
   linestyle='dashed'
)

plt.scatter(
   x=qs,
   y=ps,
   color='red',
   zorder=2
)

# %%
sns.ecdfplot(
    data = penguins,
    x = 'flipper_length_mm',
    hue = 'species',
)
# Out:
# <AxesSubplot: xlabel='flipper_length_mm', ylabel='Proportion'>

# %% [markdown]
# # PDF

# %%
sns.kdeplot(
    data = penguins,
    x = 'flipper_length_mm',
    bw_method = 0.3
)
# Out:
# <AxesSubplot: xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.kdeplot(
    data = penguins,
    x = 'flipper_length_mm',
    bw_method = 0.1,
    hue = 'species',
)
# Out:
# <AxesSubplot: xlabel='flipper_length_mm', ylabel='Density'>

# %% [markdown]
# ## Comparison of body mass with normal distribution

# %%
body_mass_stats = penguins.body_mass_g.describe()
body_mass_stats
# Out:
# count     333.000000
# mean     4207.057057
# std       805.215802
# min      2700.000000
# 25%      3550.000000
# 50%      4050.000000
# 75%      4775.000000
# max      6300.000000
# Name: body_mass_g, dtype: float64

# %%
xs = np.linspace( body_mass_stats['min'], body_mass_stats['max'], 50)
ys = scipy.stats.norm(body_mass_stats['mean'], body_mass_stats['std']).cdf(xs)

plt.plot(xs, ys, color = 'black', linestyle = 'dashed', linewidth = 2)

empiricaldist.Cdf.from_seq(penguins.body_mass_g).plot()
# Out:
# <AxesSubplot: >

# %%
xs = np.linspace( body_mass_stats['min'], body_mass_stats['max'], 50)
ys = scipy.stats.norm(body_mass_stats['mean'], body_mass_stats['std']).pdf(xs)

plt.plot(xs, ys, color = 'black', linestyle = 'dashed', linewidth = 2)

sns.kdeplot(
    data = penguins,
    x = 'body_mass_g',
)
# Out:
# <AxesSubplot: xlabel='body_mass_g', ylabel='Density'>

# %%
sns.histplot(
    data = penguins,
    x = 'body_mass_g',
    binwidth = 100,
)
# Out:
# <AxesSubplot: xlabel='body_mass_g', ylabel='Count'>

# %% [markdown]
# # Comparison numerical variables with normal distribution

# %%
penguins.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# year                   int64
# dtype: object

# %%
float_cols = penguins.select_dtypes(include=['float64']).columns

fig, ax = plt.subplots(2, 2, figsize=(15, 5))
for i, col in enumerate(float_cols):

    category_stats = penguins[col].describe()
    xs = np.linspace( category_stats['min'], category_stats['max'], 50)
    ys = scipy.stats.norm(category_stats['mean'], category_stats['std']).pdf(xs)

    ax[i//2, i%2].plot(xs, ys, color = 'black', 
             linestyle = 'dashed', 
             linewidth = 2,
             )

    sns.kdeplot(
        data = penguins,
        x = col,
        ax = ax[i//2, i%2]
    )

plt.show()

# %% [markdown]
# # Comparison of numerical variables with normal distribution by species

# %%
penguins.species.unique()
# Out:
# array(['Adelie', 'Gentoo', 'Chinstrap'], dtype=object)

# %%
float_cols = penguins.select_dtypes(include=['float64']).columns
species_arr = penguins.species.unique()

fig, ax = plt.subplots(3, 4, figsize=(15, 5))


for s, sp in enumerate(species_arr):
    for i, col in enumerate(float_cols):
        category_stats = penguins[penguins.species == sp][col].describe()
        xs = np.linspace( category_stats['min'], category_stats['max'], 50)
        ys = scipy.stats.norm(category_stats['mean'], category_stats['std']).pdf(xs)

        ax[ s , i ].plot(xs, ys, 
                 linestyle = 'dashed', 
                 linewidth = 2,
                 label = 'normal'
                 )
        
        sns.kdeplot(
            data = penguins[penguins.species == sp],
            x = col,
            ax = ax[ s , i ],
            label = sp,
            color = penguin_color[sp]
        )
        
        ax[ s , i ].legend()

plt.show()

# %% [markdown]
# # Relationships

# %% [markdown]
# ## scatterplot

# %%
sns.scatterplot(
    data = penguins,
    x = 'bill_depth_mm',
    y = 'bill_length_mm',
    alpha = 0.7,
    s = 30
)
# Out:
# <AxesSubplot: xlabel='bill_depth_mm', ylabel='bill_length_mm'>

# %% [markdown]
# ## 2D-histogram

# %%
sns.displot(
    data = penguins,
    x = 'bill_length_mm',
    y = 'bill_depth_mm',
    kind = 'hist',
    binwidth = (2,1),
    # binrange = ((30, 60), (10, 40)),
    rug = True
)

# %% [markdown]
# ## kde

# %%
sns.displot(
    data = penguins,
    x = 'bill_length_mm',
    y = 'bill_depth_mm',
    kind = 'kde',
    rug = True
)

# %% [markdown]
# ## joinplot

# %%
sns.jointplot(
    data = penguins,
    x = 'bill_depth_mm',
    y = 'bill_length_mm',
)

# %% [markdown]
# ## stripplot & swarmplot

# %%
plt.figure(figsize=(8, 8))
sns.scatterplot(
    data = penguins,
    x = 'species',
    y = 'flipper_length_mm',
    alpha = 0.2,
    hue = 'species',
    palette = penguin_color
)
# Out:
# <AxesSubplot: xlabel='species', ylabel='flipper_length_mm'>

# %%
plt.figure(figsize=(8, 8))
sns.stripplot(
    data = penguins,
    x = 'species',
    y = 'flipper_length_mm',
    alpha = 0.4,
    hue = 'species',
    palette = penguin_color
)
# Out:
# <AxesSubplot: xlabel='species', ylabel='flipper_length_mm'>

# %%
plt.figure(figsize=(8, 8))
sns.swarmplot(
    data = penguins,
    x = 'species',
    y = 'flipper_length_mm',
    alpha = 0.4,
    hue = 'species',
    palette = penguin_color
)
# Out:
# <AxesSubplot: xlabel='species', ylabel='flipper_length_mm'>

# %% [markdown]
# ## boxplot

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))

sns.boxplot(
    data = penguins,
    y = 'species',
    x = 'flipper_length_mm',
    # hue = 'species',
    palette = penguin_color,
    ax = ax,
    

)

sns.swarmplot(
    data = penguins,
    y = 'species',
    x = 'flipper_length_mm',
    alpha = 0.5,
    # hue = 'species',
    # palette = 'dark:black'
    color = 'black',
)
# Out:
# <AxesSubplot: xlabel='flipper_length_mm', ylabel='species'>

# %% [markdown]
# ## violinplot

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))

sns.violinplot(
    data = penguins,
    x = 'species',
    y = 'flipper_length_mm',
    ax = ax,
    palette = penguin_color,
)

sns.swarmplot(
    data = penguins,
    x = 'species',
    y = 'flipper_length_mm',
    color = 'black',
    alpha = 0.5,
    ax = ax,
)
# Out:
# <AxesSubplot: xlabel='species', ylabel='flipper_length_mm'>

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))

# sns.violinplot(
#     data = penguins,
#     x = 'island',
#     y = 'body_mass_g',
#     ax = ax,
#     # palette = penguin_color,
# )

sns.swarmplot(
    data = penguins,
    x = 'island',
    y = 'body_mass_g',
    # color = 'black',
    hue = 'species',
    palette = penguin_color,
    ax = ax,
)
# Out:
# <AxesSubplot: xlabel='island', ylabel='body_mass_g'>

# %% [markdown]
# ## Correlation Matrix

# %%
penguins.corr( numeric_only = True ).style.highlight_between(left=0.6, right=1,color='green')
# Out:
# <style type="text/css">
# #T_0ffb8_row0_col0, #T_0ffb8_row0_col2, #T_0ffb8_row1_col1, #T_0ffb8_row2_col0, #T_0ffb8_row2_col2, #T_0ffb8_row2_col3, #T_0ffb8_row3_col2, #T_0ffb8_row3_col3, #T_0ffb8_row4_col4 {
#   background-color: green;
# }
# </style>
# <table id="T_0ffb8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0ffb8_level0_col0" class="col_heading level0 col0" >bill_length_mm</th>
#       <th id="T_0ffb8_level0_col1" class="col_heading level0 col1" >bill_depth_mm</th>
#       <th id="T_0ffb8_level0_col2" class="col_heading level0 col2" >flipper_length_mm</th>
#       <th id="T_0ffb8_level0_col3" class="col_heading level0 col3" >body_mass_g</th>
#       <th id="T_0ffb8_level0_col4" class="col_heading level0 col4" >year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ffb8_level0_row0" class="row_heading level0 row0" >bill_length_mm</th>
#       <td id="T_0ffb8_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_0ffb8_row0_col1" class="data row0 col1" >-0.228626</td>
#       <td id="T_0ffb8_row0_col2" class="data row0 col2" >0.653096</td>
#       <td id="T_0ffb8_row0_col3" class="data row0 col3" >0.589451</td>
#       <td id="T_0ffb8_row0_col4" class="data row0 col4" >0.032657</td>
#     </tr>
#     <tr>
#       <th id="T_0ffb8_level0_row1" class="row_heading level0 row1" >bill_depth_mm</th>
#       <td id="T_0ffb8_row1_col0" class="data row1 col0" >-0.228626</td>
#       <td id="T_0ffb8_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_0ffb8_row1_col2" class="data row1 col2" >-0.577792</td>
#       <td id="T_0ffb8_row1_col3" class="data row1 col3" >-0.472016</td>
#       <td id="T_0ffb8_row1_col4" class="data row1 col4" >-0.048182</td>
#     </tr>
#     <tr>
#       <th id="T_0ffb8_level0_row2" class="row_heading level0 row2" >flipper_length_mm</th>
#       <td id="T_0ffb8_row2_col0" class="data row2 col0" >0.653096</td>
#       <td id="T_0ffb8_row2_col1" class="data row2 col1" >-0.577792</td>
#       <td id="T_0ffb8_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_0ffb8_row2_col3" class="data row2 col3" >0.872979</td>
#       <td id="T_0ffb8_row2_col4" class="data row2 col4" >0.151068</td>
#     </tr>
#     <tr>
#       <th id="T_0ffb8_level0_row3" class="row_heading level0 row3" >body_mass_g</th>
#       <td id="T_0ffb8_row3_col0" class="data row3 col0" >0.589451</td>
#       <td id="T_0ffb8_row3_col1" class="data row3 col1" >-0.472016</td>
#       <td id="T_0ffb8_row3_col2" class="data row3 col2" >0.872979</td>
#       <td id="T_0ffb8_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_0ffb8_row3_col4" class="data row3 col4" >0.021862</td>
#     </tr>
#     <tr>
#       <th id="T_0ffb8_level0_row4" class="row_heading level0 row4" >year</th>
#       <td id="T_0ffb8_row4_col0" class="data row4 col0" >0.032657</td>
#       <td id="T_0ffb8_row4_col1" class="data row4 col1" >-0.048182</td>
#       <td id="T_0ffb8_row4_col2" class="data row4 col2" >0.151068</td>
#       <td id="T_0ffb8_row4_col3" class="data row4 col3" >0.021862</td>
#       <td id="T_0ffb8_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
penguins.describe().style.highlight_max(color='green').highlight_min(color='red')
# Out:
# <style type="text/css">
# #T_8dcb8_row0_col0, #T_8dcb8_row0_col1, #T_8dcb8_row0_col2, #T_8dcb8_row6_col4, #T_8dcb8_row7_col3, #T_8dcb8_row7_col4 {
#   background-color: green;
# }
# #T_8dcb8_row0_col3, #T_8dcb8_row2_col0, #T_8dcb8_row2_col1, #T_8dcb8_row2_col2, #T_8dcb8_row2_col4 {
#   background-color: red;
# }
# </style>
# <table id="T_8dcb8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8dcb8_level0_col0" class="col_heading level0 col0" >bill_length_mm</th>
#       <th id="T_8dcb8_level0_col1" class="col_heading level0 col1" >bill_depth_mm</th>
#       <th id="T_8dcb8_level0_col2" class="col_heading level0 col2" >flipper_length_mm</th>
#       <th id="T_8dcb8_level0_col3" class="col_heading level0 col3" >body_mass_g</th>
#       <th id="T_8dcb8_level0_col4" class="col_heading level0 col4" >year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8dcb8_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_8dcb8_row0_col0" class="data row0 col0" >333.000000</td>
#       <td id="T_8dcb8_row0_col1" class="data row0 col1" >333.000000</td>
#       <td id="T_8dcb8_row0_col2" class="data row0 col2" >333.000000</td>
#       <td id="T_8dcb8_row0_col3" class="data row0 col3" >333.000000</td>
#       <td id="T_8dcb8_row0_col4" class="data row0 col4" >333.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8dcb8_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_8dcb8_row1_col0" class="data row1 col0" >43.992793</td>
#       <td id="T_8dcb8_row1_col1" class="data row1 col1" >17.164865</td>
#       <td id="T_8dcb8_row1_col2" class="data row1 col2" >200.966967</td>
#       <td id="T_8dcb8_row1_col3" class="data row1 col3" >4207.057057</td>
#       <td id="T_8dcb8_row1_col4" class="data row1 col4" >2008.042042</td>
#     </tr>
#     <tr>
#       <th id="T_8dcb8_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_8dcb8_row2_col0" class="data row2 col0" >5.468668</td>
#       <td id="T_8dcb8_row2_col1" class="data row2 col1" >1.969235</td>
#       <td id="T_8dcb8_row2_col2" class="data row2 col2" >14.015765</td>
#       <td id="T_8dcb8_row2_col3" class="data row2 col3" >805.215802</td>
#       <td id="T_8dcb8_row2_col4" class="data row2 col4" >0.812944</td>
#     </tr>
#     <tr>
#       <th id="T_8dcb8_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_8dcb8_row3_col0" class="data row3 col0" >32.100000</td>
#       <td id="T_8dcb8_row3_col1" class="data row3 col1" >13.100000</td>
#       <td id="T_8dcb8_row3_col2" class="data row3 col2" >172.000000</td>
#       <td id="T_8dcb8_row3_col3" class="data row3 col3" >2700.000000</td>
#       <td id="T_8dcb8_row3_col4" class="data row3 col4" >2007.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8dcb8_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_8dcb8_row4_col0" class="data row4 col0" >39.500000</td>
#       <td id="T_8dcb8_row4_col1" class="data row4 col1" >15.600000</td>
#       <td id="T_8dcb8_row4_col2" class="data row4 col2" >190.000000</td>
#       <td id="T_8dcb8_row4_col3" class="data row4 col3" >3550.000000</td>
#       <td id="T_8dcb8_row4_col4" class="data row4 col4" >2007.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8dcb8_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_8dcb8_row5_col0" class="data row5 col0" >44.500000</td>
#       <td id="T_8dcb8_row5_col1" class="data row5 col1" >17.300000</td>
#       <td id="T_8dcb8_row5_col2" class="data row5 col2" >197.000000</td>
#       <td id="T_8dcb8_row5_col3" class="data row5 col3" >4050.000000</td>
#       <td id="T_8dcb8_row5_col4" class="data row5 col4" >2008.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8dcb8_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_8dcb8_row6_col0" class="data row6 col0" >48.600000</td>
#       <td id="T_8dcb8_row6_col1" class="data row6 col1" >18.700000</td>
#       <td id="T_8dcb8_row6_col2" class="data row6 col2" >213.000000</td>
#       <td id="T_8dcb8_row6_col3" class="data row6 col3" >4775.000000</td>
#       <td id="T_8dcb8_row6_col4" class="data row6 col4" >2009.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8dcb8_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_8dcb8_row7_col0" class="data row7 col0" >59.600000</td>
#       <td id="T_8dcb8_row7_col1" class="data row7 col1" >21.500000</td>
#       <td id="T_8dcb8_row7_col2" class="data row7 col2" >231.000000</td>
#       <td id="T_8dcb8_row7_col3" class="data row7 col3" >6300.000000</td>
#       <td id="T_8dcb8_row7_col4" class="data row7 col4" >2009.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### heatmap

# %%
sns.heatmap(
    data = penguins.corr( numeric_only = True ),
    center = 0,
    annot = True,
    # cmap = sns.diverging_palette(100, 230, as_cmap = True),
    cmap = 'coolwarm_r',
    vmin = -1,
    vmax = 1,
    linewidths = 0.5,
)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### clustermap

# %%
sns.clustermap(
    data = penguins.corr( numeric_only = True ),
    center = 0,
    annot = True,
    # cmap = sns.diverging_palette(100, 230, as_cmap = True),
    cmap = 'coolwarm_r',
    vmin = -1,
    vmax = 1,
    linewidths = 0.5,
)

# %% [markdown]
# ### categorical value as discrete numerical value

# %%
penguins = (
    penguins
    .assign(
        numeric_sex = 
        lambda df: df.sex.replace(
            ['female', 'male'], [0,1]
        )
    )
)
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex  year  numeric_sex
# 0       3750.0    male  2007            1
# 1       3800.0  female  2007            0
# 2       3250.0  female  2007            0
# 4       3450.0  female  2007            0
# 5       3650.0    male  2007            1

# %%
sns.clustermap(
    data = penguins.corr( numeric_only = True ),
    center = 0,
    annot = True,
    # cmap = sns.diverging_palette(100, 230, as_cmap = True),
    cmap = 'coolwarm_r',
    vmin = -1,
    vmax = 1,
    linewidths = 0.5,
)

# %% [markdown]
# If we discriminate data by species, we will found
# strong correlations all over the place.

# %%
sns.FacetGrid(
    penguins, 
    col = 'species', 
    hue= 'species'
    ).map(sns.scatterplot,
        'bill_length_mm',
        'bill_depth_mm',
        alpha= 1/2,
        s= 100
        )
